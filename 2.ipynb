# %%
print("Hello World");
# Out:
# Hello World

# %%
myArr=[1,2,3,2,3,4,5,6,8,7,8,7,8,7,8];
uniqueArr=[];

# %%
for num in myArr:
    if num not in  uniqueArr:
        uniqueArr.append(num)
print(uniqueArr)
# Out:
# [1, 2, 3, 4, 5, 6, 8, 7]

# %%
print("Ali")
# Out:
# Ali

# %%
number1=float(input("Enter number 1 =>"));
number2=float(input("Enter number 2 =>"));
print(number1 + number2)
# Out:
# 13.399999999999999

# %%
x=1
print(x)
# Out:
# 1

# %%
x="Yasssin";
print(x)
# Out:
# Yasssin

# %%
# print("Operating System os ==> ");
# print("Files System fstream ==> ");


# if & switch 

# number = int(input("Enter Number =>" ));

# if number < 10:
#     print("Small");
# elif number <20:
#     print("less 20");
# else:
#     print ("Above 20")
# Out:
# Above 20

# %%
# number1=float(input("Enter number 1 =>"));
# number2=float(input("Enter number 2 =>"));
# avg=(number1 , number2 )/2;
# print(avg)
# void 
def sum(number1,number2):
    return number1+number2;

# %%
sum(2,5)
# Out:
# 7

# %%
def avg(sum ,count = 2): 
    return sum / count;

# %%
avg(sum(4,6))
# Out:
# 5.0

# %%
# Loop 
#1-While     => Ana mesh 2aref elrang 
#2- do while => 
#3- for loop => 

# Task  ===> user Enter Pass (3 , )


# count = 0
# userPassword= input("Enter Password => ")
# correctPassword = "12345"
# correct = True
# while  correct and count < 2 :
#     if userPassword == correctPassword:
#         print("Correct");
#         correct = False
#     else:
#         count +=1
#         userPassword= input(f"Enter Password Count Available {3 - count} : ")
# Out:
# Correct
