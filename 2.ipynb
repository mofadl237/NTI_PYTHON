# %%
print("Hello World");
# Out:
# Hello World

# %%
myArr=[1,2,3,2,3,4,5,6,8,7,8,7,8,7,8];
uniqueArr=[];

# %%
for num in myArr:
    if num not in  uniqueArr:
        uniqueArr.append(num)
print(uniqueArr)
# Out:
# [1, 2, 3, 4, 5, 6, 8, 7]

# %%
print(uniqueArr)
